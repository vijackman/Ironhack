# %% [markdown]
# ## 1. Importing libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. Importing datasets and analyzing data

# %%
young=pd.read_csv('./Young_preferences.csv')
young.head(3)
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0      1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1      2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2      5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
#
#    Number of siblings  Gender  Left - right handed                Education  \
# 0                 1.0  female         right handed  college/bachelor degree
# 1                 2.0  female         right handed  college/bachelor degree
# 2                 2.0  female         right handed         secondary school
#
#    Only child  Village - town  House - block of flats
# ...

# %%
young.shape
# Out:
# (1010, 150)

# %% [markdown]
# ### 2.1 Checking Columns and cleaning Missing data

# %%
young.columns
# Out:
# Index(['Music', 'Slow songs or fast songs', 'Dance', 'Folk', 'Country',
#        'Classical music', 'Musical', 'Pop', 'Rock', 'Metal or Hardrock',
#        ...
#        'Age', 'Height', 'Weight', 'Number of siblings', 'Gender',
#        'Left - right handed', 'Education', 'Only child', 'Village - town',
#        'House - block of flats'],
#       dtype='object', length=150)

# %%
young.isna().sum()
# Out:
# Music                       3
# Slow songs or fast songs    2
# Dance                       4
# Folk                        5
# Country                     5
#                            ..
# Left - right handed         3
# Education                   1
# Only child                  2
# Village - town              4
# House - block of flats      4
# Length: 150, dtype: int64

# %%
young=young.fillna(0)

# %% [markdown]
# ### 2.2 Using Heatmap to find correlations between data

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(16,10))
sns.heatmap(young.corr(),annot=True,linewidths=.5)

# %% [markdown]
# ### 2.3 Finding and identifying Outliers

# %%
fig, ax = plt.subplots(figsize=(16,10))
sns.boxplot(data=young)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 2.4 Checking if distribution is skewed

# %%
fifa.hist(figsize=(12,9))
plt.show()

# %% [markdown]
# ## 3. Data processing

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
young.head(3)
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Education_doctorate degree  \
# 0      1.0  5.0   5.0                1.0  ...                           0
# 1      2.0  3.0   5.0                4.0  ...                           0
# 2      5.0  3.0   5.0                3.0  ...                           0
#
#    Education_masters degree  Education_primary school  \
# 0                         0                         0
# 1                         0                         0
# 2                         0                         0
#
#    Education_secondary school  Only child_no  Only child_yes  \
# 0                           0              1               0
# ...

# %% [markdown]
# ### 3.1 Selecting only columns with numerical data in it to check results / Turnung 'Release Clause' to integers

# %%
for item in young:
# Out:
#   File "<ipython-input-35-3f1ccae91550>", line 2
#     return item
#     ^
# SyntaxError: 'return' outside function

# %%
numerical=['Music', 'Slow songs or fast songs', 'Dance', 'Folk', 'Country',
       'Classical music', 'Musical', 'Pop', 'Rock', 'Metal or Hardrock', 'Age', 'Height', 'Weight', 'Number of siblings', 'Education_doctorate degree', 'Education_masters degree',
       'Education_primary school', 'Education_secondary school',
       'Only child_no', 'Only child_yes', 'Village - town_city',
       'Village - town_village', 'House - block of flats_block of flats',
       'House - block of flats_house/bungalow']
young[numerical].head(3)
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Education_doctorate degree  \
# 0      1.0  5.0   5.0                1.0  ...                           0
# 1      2.0  3.0   5.0                4.0  ...                           0
# 2      5.0  3.0   5.0                3.0  ...                           0
#
#    Education_masters degree  Education_primary school  \
# 0                         0                         0
# 1                         0                         0
# 2                         0                         0
#
#    Education_secondary school  Only child_no  Only child_yes  \
# 0                           0              1               0
# ...

# %%
pc1 = pca.transform(young[numerical])[:, 0]
pc2 = pca.transform(young[numerical])[:, 1]

# %%
plt.scatter(pc1, pc2,c=young['Labels'])

# %% [markdown]
# ### 3.2 Using Kmeans

# %%
scaler = StandardScaler()

# %%
numerical_kmeans = ['Overall','Potential','Composure','Marking','StandingTackle','SlidingTackle',
           'GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes']
fifa[numerical_kmeans].head(3)

# %% [markdown]
# ### 3.3 Comparing results

# %% [markdown]
# ### 3.4 using Get Dummies to process data with string columns

# %%
young

# %%
young=pd.get_dummies(young,drop_first=True)
young.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Education_doctorate degree  \
# 0      1.0  5.0   5.0                1.0  ...                           0
# 1      2.0  3.0   5.0                4.0  ...                           0
# 2      5.0  3.0   5.0                3.0  ...                           0
# 3      1.0  2.0   2.0                1.0  ...                           0
# 4      3.0  5.0   3.0                1.0  ...                           0
#
#    Education_masters degree  Education_primary school  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-96cdbe2700bf> in <module>
# ----> 1 model.fit(X,y)
#       2 model.coef_
#
# NameError: name 'model' is not defined
